# %% [markdown]
# # Dataset Financial Question and Answer

# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/FinGPT/fingpt-fiqa_qa/data/train-00000-of-00001-ab79bf9300210e98.parquet")

# %%
df.columns
# Out:
# Index(['input', 'output', 'instruction'], dtype='str')

# %%
df.shape
# Out:
# (17110, 3)

# %%
df.head()
# Out:
#                                                input  \
# 0  What is considered a business expense on a bus...
# 1  Claiming business expenses for a business with...
# 2  Transferring money from One business checking ...
# 3  Having a separate bank account for business/in...
# 4  Having a separate bank account for business/in...
#
#                                               output  \
# 0  The IRS Guidance pertaining to the subject.  I...
# 1  Yes you can claim your business deductions if ...
# 2  You should have separate files for each of the...
# 3  Having a separate checking account for the bus...
# 4  You don't specify which country you are in, so...
#
#                                          instruction
# 0  Utilize your financial knowledge, give your an...
# 1  Offer your insights or judgment on the input f...
# 2  Based on your financial expertise, provide you...
# 3  Share your insights or perspective on the fina...
# 4  Offer your thoughts or opinion on the input fi...

# %% [markdown]
# ## Samples

# %%
index = 0
print("input: ", df["input"][index])
print("output: ", df["output"][index])
print("instruction: ", df["instruction"][index])
# Out:
# input:  What is considered a business expense on a business trip?
# ...

# %%
index = 1
print("input: ", df["input"][index])
print("output: ", df["output"][index])
print("instruction: ", df["instruction"][index])
# Out:
# input:  Claiming business expenses for a business with no income
# ...

# %%
index = 100
print("input: ", df["input"][index])
print("output: ", df["output"][index])
print("instruction: ", df["instruction"][index])
# Out:
# input:  How can I lookup the business associated with a FEIN?
# output:  If the organization is a non-profit. You can search by EIN on Charity Navigator's website FOR FREE. https://www.charitynavigator.org/
# instruction:  Utilize your financial knowledge, give your answer or opinion to the input question or subject . Answer format is not limited.

# %% [markdown]
# ## Missing data?

# %%
df.notna().sum()
# Out:
# input          17110
# output         17110
# instruction    17110
# dtype: int64

# %%
df.isnull().sum()
# Out:
# input          0
# output         0
# instruction    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# input          0
# output         0
# instruction    0
# dtype: int64

# %%
((df == "") | (df == " ")).sum()
# Out:
# input          0
# output         0
# instruction    0
# dtype: int64

# %%
for column in df.columns: 
    print(df[column].str.match(r'^\s*$').sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# No missing values!

# %%
df.describe()
# Out:
#                                                     input output  \
# count                                               17110  17110
# unique                                               6648  17071
# top     What options do I have at 26 years old, with 1...    nan
# freq                                                   23     38
#
#                                               instruction
# count                                               17110
# unique                                                  5
# top     Utilize your financial knowledge, give your an...
# freq                                                 3422

# %% [markdown]
# There are 5 types of instructions:

# %%
for i, prompt in enumerate(df.instruction.unique()):
    print(f"Prompt {i}:", prompt, "\n\n")
# Out:
# Prompt 0: Utilize your financial knowledge, give your answer or opinion to the input question or subject . Answer format is not limited.
#
#
# Prompt 1: Offer your insights or judgment on the input financial query or topic using your financial expertise. Reply as normal question answering
#
#
# Prompt 2: Based on your financial expertise, provide your response or viewpoint on the given financial question or topic. The response format is open.
#
#
# Prompt 3: Share your insights or perspective on the financial matter presented in the input.
#
#
# Prompt 4: Offer your thoughts or opinion on the input financial query or topic using your financial background.

# %% [markdown]
# # Dataset: S&P 500 SEC Fillings
#
# To understand each of the items go to the [wiki page](https://en.wikipedia.org/wiki/Form_10-K).
#
# How to directly extract from the [sec api](https://sec-api.io/docs/sec-filings-item-extraction-api/python-example).

# %%
from datasets import load_dataset

ds = load_dataset("jlohding/sp500-edgar-10k")
# Out:
# data/2013.parquet:   0%|          | 0.00/71.6M [00:00<?, ?B/s]
# data/2014.parquet:   0%|          | 0.00/72.9M [00:00<?, ?B/s]
# data/2015.parquet:   0%|          | 0.00/72.2M [00:00<?, ?B/s]
# data/2016.parquet:   0%|          | 0.00/74.6M [00:00<?, ?B/s]
# data/2017.parquet:   0%|          | 0.00/74.8M [00:00<?, ?B/s]
# data/2018.parquet:   0%|          | 0.00/76.7M [00:00<?, ?B/s]
# data/2019.parquet:   0%|          | 0.00/76.9M [00:00<?, ?B/s]
# data/2020.parquet:   0%|          | 0.00/75.6M [00:00<?, ?B/s]
# data/2021.parquet:   0%|          | 0.00/80.2M [00:00<?, ?B/s]
# data/2022.parquet:   0%|          | 0.00/79.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/6282 [00:00<?, ? examples/s]

# %%
df_train = ds["train"].to_pandas()

# %%
ds["train"]
# Out:
# Dataset({
#     features: ['cik', 'sic', 'company', 'date', 'item_1', 'item_1A', 'item_1B', 'item_2', 'item_3', 'item_4', 'item_5', 'item_6', 'item_7', 'item_7A', 'item_8', 'item_9', 'item_9A', 'item_9B', 'item_10', 'item_11', 'item_12', 'item_13', 'item_14', 'item_15', 'ret', 'mkt_cap', '1_day_return', '3_day_return', '5_day_return', '10_day_return', '20_day_return', '40_day_return', '60_day_return', '80_day_return', '100_day_return', '150_day_return', '252_day_return', '__index_level_0__'],
#     num_rows: 6282
# })

# %%
df_train.columns
# Out:
# Index(['cik', 'sic', 'company', 'date', 'item_1', 'item_1A', 'item_1B',
#        'item_2', 'item_3', 'item_4', 'item_5', 'item_6', 'item_7', 'item_7A',
#        'item_8', 'item_9', 'item_9A', 'item_9B', 'item_10', 'item_11',
#        'item_12', 'item_13', 'item_14', 'item_15', 'ret', 'mkt_cap',
#        '1_day_return', '3_day_return', '5_day_return', '10_day_return',
#        '20_day_return', '40_day_return', '60_day_return', '80_day_return',
#        '100_day_return', '150_day_return', '252_day_return',
#        '__index_level_0__'],
#       dtype='str')

# %%
"western digital" in df_train["company"].str.lower()[10]
# Out:
# True

# %%
for index, word in enumerate(df_train["company"].str.lower()):
    
    if "western digital" in word:
        print(index)
# Out:
# 10
# 815
# 1272
# 1778
# 1908
# 2809
# 3247
# 3471
# 4297
# 4788
# 4843
# 5726
# 6203

# %%
from IPython.display import Markdown, display
display(Markdown(df_train.item_1[0]))
# Out:
# Item 1. BUSINESS
# Overview
# C.H. Robinson Worldwide, Inc. (“C.H. Robinson,” “the company,” “we,” “us,” or “our”) is one of the largest third party logistics companies in the world with 2009 consolidated total revenues of $7.6 billion. We provide freight transportation services and logistics solutions to companies of all sizes, in a wide variety of industries. During 2009 we handled approximately 7.5 million shipments for more than 35,000 customers. We operate through a network of 235 offices, which we call branches, in North America, Europe, Asia, South America, Australia, and the Middle East. We have developed global multimodal transportation and distribution networks to provide logistics services worldwide. As a result, we have the capability of facilitating most aspects of the supply chain on behalf of our customers.
# ...

# %% [markdown]
# # Financial QA
#
# https://huggingface.co/datasets/virattt/financial-qa-10K

# %%
from datasets import load_dataset

ds = load_dataset("virattt/financial-qa-10K")
# Out:
# README.md:   0%|          | 0.00/419 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7000 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'answer', 'context', 'ticker', 'filing'],
#         num_rows: 7000
#     })
# })

# %%
df2 = ds["train"].to_pandas()

# %%
df2.head()
# Out:
#                                             question  \
# 0  What area did NVIDIA initially focus on before...
# 1  What are some of the recent applications of GP...
# 2  What significant invention did NVIDIA create i...
# 3  How does NVIDIA's platform strategy contribute...
# 4  What does NVIDIA's CUDA programming model enable?
#
#                                               answer  \
# 0           NVIDIA initially focused on PC graphics.
# 1  Recent applications of GPU-powered deep learni...
# 2                   NVIDIA invented the GPU in 1999.
# 3  NVIDIA's platform strategy brings together har...
# 4  NVIDIA's CUDA programming model opened the par...
#
#                                              context ticker    filing
# 0  Since our original focus on PC graphics, we ha...   NVDA  2023_10K
# 1  Some of the most recent applications of GPU-po...   NVDA  2023_10K
# 2  Our invention of the GPU in 1999 defined moder...   NVDA  2023_10K
# ...

# %%
df2.question[0]
# Out:
# 'What area did NVIDIA initially focus on before expanding to other computationally intensive fields?'

# %%
df2.answer[0]
# Out:
# 'NVIDIA initially focused on PC graphics.'

# %%
df2.context[0]
# Out:
# 'Since our original focus on PC graphics, we have expanded to several other large and important computationally intensive fields.'

# %%
df2.filing.unique()
# Out:
# <ArrowStringArray>
# ['2023_10K']
# Length: 1, dtype: str
